# %% [markdown]
# # LAB 1: Thuật Toán Tìm Kiếm Mù - Nhập Môn Trí Tuệ Nhân Tạo
#
# - **Thời lượng**: 2,5 giờ
# - **Mục đích**: Trang bị kiến thức và kỹ năng thực hành về các thuật toán tìm kiếm mù, cụ thể là Tìm kiếm theo Chiều rộng (Breadth-First Search - BFS) và Tìm kiếm theo Chiều sâu (Depth-First Search - DFS), áp dụng trên đồ thị không trọng số và có trọng số.
# - **Yêu cầu**: Sinh viên cần chuẩn bị máy tính cài đặt Python (phiên bản 3.7 trở lên) và môi trường thực thi Jupyter Notebook hoặc Google Colab.
#
# ## Mục Tiêu
# 1. Hiểu rõ khái niệm và cơ chế hoạt động của các thuật toán tìm kiếm mù trong trí tuệ nhân tạo.
# 2. Thành thạo triển khai BFS và DFS trên các đồ thị vô hướng, bao gồm đồ thị không trọng số và có trọng số.
# 3. Phân tích hạn chế của BFS và DFS khi áp dụng trên đồ thị có trọng số.
# 4. Thực hiện minh họa thủ công và lập trình với chú thích rõ ràng để kiểm chứng kết quả tìm kiếm.
#
# ## Cơ Sở Lý Thuyết
#
# ### 1. Tìm Kiếm Mù
# Tìm kiếm mù (Uninformed Search) là các thuật toán tìm kiếm không sử dụng thông tin heuristic, duyệt qua không gian trạng thái theo cách có hệ thống, dựa trên cấu trúc bài toán.
#
# ### 2. Tìm Kiếm theo Chiều Rộng (BFS)
# - **Nguyên lý**: Khám phá tất cả các nút ở mức hiện tại trước khi chuyển sang mức tiếp theo.
# - **Cấu trúc dữ liệu**: Hàng đợi (Queue).
# - **Đặc điểm**:
#   - Trong đồ thị không trọng số, BFS đảm bảo tìm đường đi ngắn nhất (theo số cạnh).
#   - Trong đồ thị có trọng số, BFS không đảm bảo đường đi có tổng trọng số nhỏ nhất, vì nó không xem xét trọng số của các cạnh.
#
# ### 3. Tìm Kiếm theo Chiều Sâu (DFS)
# - **Nguyên lý**: Khám phá một nhánh đến tận cùng trước khi quay lại thử nhánh khác.
# - **Cấu trúc dữ liệu**: Ngăn xếp (Stack) hoặc đệ quy.
# - **Đặc điểm**:
#   - DFS không đảm bảo đường đi ngắn nhất trong cả đồ thị không trọng số và có trọng số.
#   - Kết quả phụ thuộc vào thứ tự duyệt các nút kề.
#
# ### 4. Đồ Thị Không Trọng Số và Có Trọng Số
# - **Đồ thị không trọng số**: Các cạnh có trọng số ngầm định bằng 1. BFS tối ưu theo số cạnh.
# - **Đồ thị có trọng số**: Các cạnh có trọng số khác nhau (ví dụ: chi phí, khoảng cách). BFS và DFS không được thiết kế để tối ưu hóa tổng trọng số, dẫn đến kết quả không tối ưu.
#
# ### 5. Bài Toán
# Cho các đồ thị vô hướng (không trọng số và có trọng số) biểu diễn mạng lưới hoặc mê cung. Nhiệm vụ là tìm đường đi từ nút bắt đầu (**S**) đến nút đích (**G** hoặc **H**) bằng BFS và DFS, thông qua minh họa thủ công và lập trình với chú thích chi tiết.

# %% [markdown]
# ## Hướng Dẫn Thực Hành
#
# ### Phần 1: Thiết Lập Môi Trường
# - **Yêu cầu**: Python 3.7+ và Jupyter Notebook hoặc Google Colab.
# - **Hướng dẫn**:
#   1. Mở file `.ipynb` này trong Jupyter Notebook hoặc tải lên Google Colab.
#   2. Chạy các ô mã Python để đảm bảo môi trường hoạt động.
#
# ### Phần 2: Minh Họa Thủ Công BFS và DFS
#
# #### Đồ Thị Mẫu 1: Không Trọng Số
# ##### Mermaid Diagram
# ```mermaid
# graph TD
#     S --> A
#     S --> B
#     S --> C
#     A --> D
#     B --> E
#     D --> F
#     E --> G
# ```
# - **Các cạnh**: S-A, S-B, S-C, A-D, B-E, D-F, E-G.
# - **Mục tiêu**: Tìm đường từ S đến G.
#
# **Minh họa BFS**:
# 1. Khởi tạo: Hàng đợi = [(S, [S])], Đã thăm = {S}
# 2. Lấy S, thêm A, B, C: Hàng đợi = [(A, [S, A]), (B, [S, B]), (C, [S, C])], Đã thăm = {S, A, B, C}
# 3. Lấy A, thêm D: Hàng đợi = [(B, [S, B]), (C, [S, C]), (D, [S, A, D])], Đã thăm = {S, A, B, C, D}
# 4. Lấy B, thêm E: Hàng đợi = [(C, [S, C]), (D, [S, A, D]), (E, [S, B, E])], Đã thăm = {S, A, B, C, D, E}
# 5. Lấy C, không có kề mới: Hàng đợi = [(D, [S, A, D]), (E, [S, B, E])]
# 6. Lấy D, thêm F: Hàng đợi = [(E, [S, B, E]), (F, [S, A, D, F])], Đã thăm = {S, A, B, C, D, E, F}
# 7. Lấy E, thêm G: G là đích, trả về [S, B, E, G]
#
# **Kết quả**: Đường đi BFS: S → B → E → G (độ dài 3, ngắn nhất).
#
# **Minh họa DFS** :
# 1. Khởi tạo: Ngăn xếp = [(S, [S])], Đã thăm = {S}
# 2. Lấy S, thêm A: Ngăn xếp = [(A, [S, A])], Đã thăm = {S, A}
# 3. Lấy A, thêm D: Ngăn xếp = [(D, [S, A, D])], Đã thăm = {S, A, D}
# 4. Lấy D, thêm F: Ngăn xếp = [(F, [S, A, D, F])], Đã thăm = {S, A, D, F}
# 5. Lấy F, không có kề mới: Ngăn xếp rỗng, quay lại S.
# 6. Từ S, thêm B: Ngăn xếp = [(B, [S, B])], Đã thăm = {S, A, D, F, B}
# 7. Lấy B, thêm E: Ngăn xếp = [(E, [S, B, E])], Đã thăm = {S, A, D, F, B, E}
# 8. Lấy E, thêm G: G là đích, trả về [S, B, E, G]
#
# **Kết quả**: Đường đi DFS: S → B → E → G.

# %% [markdown]
# #### Đồ Thị Mẫu 5: Có Trọng Số
# ##### Mermaid Diagram
# ```mermaid
# graph TD
#     S -->|1| A
#     S -->|2| B
#     S -->|3| C
#     A -->|4| D
#     B -->|5| G
#     D -->|6| G
#     A -->|3| G
# ```
# - **Các cạnh và trọng số**: S-A: 1, S-B: 2, S-C: 3, A-D: 4, B-G: 5, D-G: 6, A-G: 3.
# - **Mục tiêu**: Tìm đường từ S đến G.
#
# **Minh họa BFS**:
# 1. Khởi tạo: Hàng đợi = [(S, [S], 0)], Đã thăm = {S}
# 2. Lấy S, thêm A, B, C: Hàng đợi = [(A, [S, A], 1), (B, [S, B], 2), (C, [S, C], 3)], Đã thăm = {S, A, B, C}
# 3. Lấy A, thêm D, G: Hàng đợi = [(B, [S, B], 2), (C, [S, C], 3), (D, [S, A, D], 5), (G, [S, A, G], 4)], Đã thăm = {S, A, B, C, D, G}
# 4. Lấy B, thêm G (đã thăm): Hàng đợi = [(C, [S, C], 3), (D, [S, A, D], 5), (G, [S, A, G], 4)]
# 5. Lấy G: G là đích, trả về [S, A, G], trọng số: 4
#
# **Kết quả**: Đường đi BFS: S → A → G (trọng số: 4). **Lưu ý**: BFS không đảm bảo tổng trọng số nhỏ nhất.
#
# **Minh họa DFS**:
# 1. Khởi tạo: Ngăn xếp = [(S, [S], 0)], Đã thăm = {S}
# 2. Lấy S, thêm A: Ngăn xếp = [(A, [S, A], 1)], Đã thăm = {S, A}
# 3. Lấy A, thêm D, G: Ngăn xếp = [(D, [S, A, D], 5), (G, [S, A, G], 4)], Đã thăm = {S, A, D, G}
# 4. Lấy G: G là đích, trả về [S, A, G], trọng số: 4
#
# **Kết quả**: Đường đi DFS: S → A → G (trọng số: 4). **Lưu ý**: DFS không đảm bảo tổng trọng số nhỏ nhất.

# %% [markdown]
# ### Phần 3: Triển Khai Mã Python
#
# #### BFS trên Đồ Thị Không Trọng Số
# Chạy ô mã dưới đây để kiểm chứng BFS trên **Đồ thị mẫu 1**.

# %%
from collections import deque

def bfs(graph, start, goal):
    # Khởi tạo hàng đợi với nút bắt đầu và đường đi ban đầu
    queue = deque([(start, [start])])
    # Khởi tạo tập hợp các nút đã thăm để tránh lặp
    visited = set([start])
    
    # Lặp cho đến khi hàng đợi rỗng
    while queue:
        # Lấy nút đầu tiên và đường đi tương ứng từ hàng đợi
        (node, path) = queue.popleft()
        # Kiểm tra nếu nút hiện tại là đích
        if node == goal:
            return path
        # Duyệt qua các nút kề của nút hiện tại
        for neighbor in graph[node]:
            # Nếu nút kề chưa được thăm
            if neighbor not in visited:
                # Thêm nút kề vào tập đã thăm
                visited.add(neighbor)
                # Thêm nút kề và đường đi mới vào hàng đợi
                queue.append((neighbor, path + [neighbor]))
    # Trả về None nếu không tìm thấy đường đi
    return None

# Định nghĩa Đồ thị mẫu 1 (không trọng số)
graph1 = {
    'S': ['A', 'B', 'C'],
    'A': ['S', 'D'],
    'B': ['S', 'E'],
    'C': ['S'],
    'D': ['A', 'F'],
    'E': ['B', 'G'],
    'F': ['D'],
    'G': ['E']
}

# Chạy BFS và in kết quả
path = bfs(graph1, 'S', 'G')
print("Đường đi BFS trên Đồ thị mẫu 1:", path)
# Out:
# Đường đi BFS trên Đồ thị mẫu 1: ['S', 'B', 'E', 'G']

# %% [markdown]
# #### DFS trên Đồ Thị Không Trọng Số
# Chạy ô mã dưới đây để kiểm chứng DFS trên **Đồ thị mẫu 1**.

# %%
def dfs(graph, start, goal, visited=None, path=None):
    # Khởi tạo tập đã thăm và đường đi nếu chưa có
    if visited is None:
        visited = set()
    if path is None:
        path = [start]
    
    # Thêm nút hiện tại vào tập đã thăm
    visited.add(start)
    # Kiểm tra nếu nút hiện tại là đích
    if start == goal:
        return path
    
    # Duyệt qua các nút kề của nút hiện tại
    for neighbor in graph[start]:
        # Nếu nút kề chưa được thăm
        if neighbor not in visited:
            # Gọi đệ quy DFS trên nút kề với đường đi mới
            new_path = dfs(graph, neighbor, goal, visited, path + [neighbor])
            # Nếu tìm thấy đường đi, trả về
            if new_path:
                return new_path
    # Trả về None nếu không tìm thấy đường đi
    return None

# Định nghĩa Đồ thị mẫu 1 (không trọng số)
graph1 = {
    'S': ['A', 'B', 'C'],
    'A': ['S', 'D'],
    'B': ['S', 'E'],
    'C': ['S'],
    'D': ['A', 'F'],
    'E': ['B', 'G'],
    'F': ['D'],
    'G': ['E']
}

# Chạy DFS và in kết quả
path = dfs(graph1, 'S', 'G')
print("Đường đi DFS trên Đồ thị mẫu 1:", path)
# Out:
# Đường đi DFS trên Đồ thị mẫu 1: ['S', 'B', 'E', 'G']

# %% [markdown]
# #### BFS trên Đồ Thị Có Trọng Số
# Chạy ô mã dưới đây để kiểm chứng BFS trên **Đồ thị mẫu 5**.

# %%
from collections import deque

def bfs_weighted(graph, start, goal):
    # Khởi tạo hàng đợi với nút bắt đầu, đường đi, và tổng trọng số
    queue = deque([(start, [start], 0)])
    # Khởi tạo tập hợp các nút đã thăm
    visited = set([start])
    
    # Lặp cho đến khi hàng đợi rỗng
    while queue:
        # Lấy nút, đường đi, và tổng trọng số từ đầu hàng đợi
        (node, path, total_weight) = queue.popleft()
        # Kiểm tra nếu nút hiện tại là đích
        if node == goal:
            return path, total_weight
        # Duyệt qua các nút kề và trọng số tương ứng
        for neighbor, weight in graph[node]:
            # Nếu nút kề chưa được thăm
            if neighbor not in visited:
                # Thêm nút kề vào tập đã thăm
                visited.add(neighbor)
                # Thêm nút kề, đường đi mới, và tổng trọng số cập nhật vào hàng đợi
                queue.append((neighbor, path + [neighbor], total_weight + weight))
    # Trả về None và 0 nếu không tìm thấy đường đi
    return None, 0

# Định nghĩa Đồ thị mẫu 5 (có trọng số)
graph5 = {
    'S': [('A', 1), ('B', 2), ('C', 3)],
    'A': [('S', 1), ('D', 4), ('G', 3)],
    'B': [('S', 2), ('G', 5)],
    'C': [('S', 3)],
    'D': [('A', 4), ('G', 6)],
    'G': [('B', 5), ('D', 6), ('A', 3)]
}

# Chạy BFS và in kết quả
path, weight = bfs_weighted(graph5, 'S', 'G')
print("Đường đi BFS trên Đồ thị mẫu 5:", path, "Tổng trọng số:", weight)
# Out:
# Đường đi BFS trên Đồ thị mẫu 5: ['S', 'A', 'G'] Tổng trọng số: 4

# %% [markdown]
# #### DFS trên Đồ Thị Có Trọng Số
# Chạy ô mã dưới đây để kiểm chứng DFS trên **Đồ thị mẫu 5**.

# %%
def dfs_weighted(graph, start, goal, visited=None, path=None, total_weight=0):
    # Khởi tạo tập đã thăm và đường đi nếu chưa có
    if visited is None:
        visited = set()
    if path is None:
        path = [start]
    
    # Thêm nút hiện tại vào tập đã thăm
    visited.add(start)
    # Kiểm tra nếu nút hiện tại là đích
    if start == goal:
        return path, total_weight
    
    # Duyệt qua các nút kề và trọng số tương ứng
    for neighbor, weight in graph[start]:
        # Nếu nút kề chưa được thăm
        if neighbor not in visited:
            # Gọi đệ quy DFS trên nút kề với đường đi và tổng trọng số mới
            new_path, new_weight = dfs_weighted(graph, neighbor, goal, visited, path + [neighbor], total_weight + weight)
            # Nếu tìm thấy đường đi, trả về
            if new_path:
                return new_path, new_weight
    # Trả về None và 0 nếu không tìm thấy đường đi
    return None, 0

# Định nghĩa Đồ thị mẫu 5 (có trọng số)
graph5 = {
    'S': [('A', 1), ('B', 2), ('C', 3)],
    'A': [('S', 1), ('D', 4), ('G', 3)],
    'B': [('S', 2), ('G', 5)],
    'C': [('S', 3)],
    'D': [('A', 4), ('G', 6)],
    'G': [('B', 5), ('D', 6), ('A', 3)]
}

# Chạy DFS và in kết quả
path, weight = dfs_weighted(graph5, 'S', 'G')
print("Đường đi DFS trên Đồ thị mẫu 5:", path, "Tổng trọng số:", weight)
# Out:
# Đường đi DFS trên Đồ thị mẫu 5: ['S', 'A', 'D', 'G'] Tổng trọng số: 11

# %% [markdown]
# ## Bài Tập Thực Hành Trong Lớp
#
# ### Đồ Thị Mẫu Khác
#
# #### Đồ Thị Mẫu 2: Có Chu Trình, Không Trọng Số
# ##### Mermaid Diagram
# ```mermaid
# graph TD
#     S --> A
#     S --> B
#     A --> B
#     A --> C
#     B --> D
#     C --> D
#     D --> G
# ```
# - **Các cạnh**: S-A, S-B, A-B, A-C, B-D, C-D, D-G.
#
# #### Đồ Thị Mẫu 3: Không Có Đường Đi Tới Đích, Không Trọng Số
# ##### Mermaid Diagram
# ```mermaid
# graph TD
#     S --> A
#     S --> B
#     A --> C
#     B --> D
# ```
# - **Các cạnh**: S-A, S-B, A-C, B-D.
#
# #### Đồ Thị Mẫu 4: Dạng Lưới, Không Trọng Số
# ##### Mermaid Diagram
# ```mermaid
# graph TD
#     S --> A
#     S --> C
#     A --> B
#     A --> D
#     B --> E
#     C --> D
#     C --> F
#     D --> E
#     E --> G
#     F --> G
# ```
#
# - **Các cạnh**: S-A, S-C, A-B, A-D, B-E, C-D, C-F, D-E, E-G, F-G.
#
# ### Câu Hỏi Lý Thuyết
# 1. Giải thích tại sao BFS đảm bảo đường đi ngắn nhất trên đồ thị không trọng số nhưng không đảm bảo trên đồ thị có trọng số. Sử dụng **Đồ thị mẫu 5** để minh họa.
# 2. Trong **Đồ thị mẫu 2** (có chu trình), làm thế nào để BFS và DFS tránh lặp vô hạn?
#
# ### Bài Tập Minh Họa Thủ Công
# 1. Thực hiện BFS và DFS thủ công trên **Đồ thị mẫu 2**. Ghi lại trạng thái hàng đợi/ngăn xếp và tập đã thăm ở mỗi bước.
# 2. Với **Đồ thị mẫu 3**, chạy BFS và DFS thủ công. Ghi lại kết quả khi không tìm thấy G.
#
# ### Bài Tập Lập Trình
# 1. Sử dụng BFS và DFS trên **Đồ thị mẫu 2** . Thêm chú thích chi tiết vào mã của bạn.
# 2. Sửa mã BFS để đếm số nút đã thăm trên **Đồ thị mẫu 4**. In ra kết quả và đảm bảo mã có chú thích đầy đủ.

# %% [markdown]
# # Trả lời câu hỏi lý thuyết
# 1. Trên đồ thị không trọng số:
# BFS duyệt theo từng lớp (level), từ đỉnh nguồn đi đến tất cả các đỉnh ở khoảng cách 1, sau đó đến khoảng cách 2, v.v.
# Vì mỗi cạnh có "trọng số 1", đường đi đầu tiên đến một đỉnh chính là đường đi ngắn nhất (ít cạnh nhất).
#     Trên đồ thị có trọng số:
# BFS không xét đến trọng số, chỉ xét số bước.
# Có thể chọn đường đi ít bước nhưng tổng trọng số lớn hơn → không đảm bảo ngắn nhất.
# graph TD
#     S -->|2| A
#     S -->|5| C
#     A -->|3| B
#     A -->|4| D
#     B -->|6| E
#     C -->|7| D
#     C -->|9| F
#     D -->|8| E
#     E -->|10| H
#     F -->|12| G
#     G -->|15| H
# Hai đường từ S đến H:
# Đường 1 (ít bước, BFS có thể chọn):
# S → C → F → G → H
# Trọng số: 5 + 9 + 12 + 15 = 41
# Đường 2 (nhiều bước hơn):
# S → A → B → E → H
# Trọng số: 2 + 3 + 6 + 10 = 21
#  BFS chọn đường 1 (4 bước) vì không xét trọng số, sai về mặt chi phí.
#  Đúng phải dùng Dijkstra để chọn đường có tổng trọng số nhỏ hơn.
# 2. graph TD
#     S --> A
#     S --> B
#     A --> B
#     A --> C
#     B --> D
#     C --> D
#     D --> G
# Giải pháp:
# Dùng một tập visited (hoặc mảng visited[]) để lưu các đỉnh đã duyệt.
#
# Trước khi thêm đỉnh vào queue (BFS) hoặc stack (DFS), kiểm tra xem đỉnh đó đã nằm trong visited chưa.
#
# Nếu rồi → bỏ qua → tránh lặp lại và vô hạn trong chu trình như A → B → D → A...

# %% [markdown]
# # Bài tập minh hoạ thủ công
# # bài 1
# 1. BFS
# 1.Khởi tạo:
#     Hàng đợi = [(S, [S], 0)]
#     Đã thăm = {S}
# 2.Lấy S, thêm A (2), C (5):
#     Hàng đợi = [(A, [S, A], 2), (C, [S, C], 5)]
#     Đã thăm = {S, A, C}
# 3.Lấy A, thêm B (3), D (4):
#     Tổng trọng số đến B = 2 + 3 = 5
#     Tổng trọng số đến D = 2 + 4 = 6
#     Hàng đợi = [(C, [S, C], 5), (B, [S, A, B], 5), (D, [S, A, D], 6)]
#     Đã thăm = {S, A, C, B, D}
# 4.Lấy C, thêm F (9), D đã thăm → bỏ qua:
#     Tổng trọng số đến F = 5 + 9 = 14
#     Hàng đợi = [(B, [S, A, B], 5), (D, [S, A, D], 6), (F, [S, C, F], 14)]
#     Đã thăm = {S, A, C, B, D, F}
# 5.Lấy B, thêm E (6):
#     Tổng trọng số đến E = 5 + 6 = 11
#     Hàng đợi = [(D, [S, A, D], 6), (F, [S, C, F], 14), (E, [S, A, B, E], 11)]
#     Đã thăm = {S, A, C, B, D, F, E}
# 6.Lấy D, thêm E (8), đã thăm → bỏ qua.
# 7.Lấy F, thêm G (12):
#     Tổng trọng số đến G = 14 + 12 = 26
#     Hàng đợi = [(E, [S, A, B, E], 11), (G, [S, C, F, G], 26)]
#     Đã thăm = {S, A, C, B, D, F, E, G}
# 8.Lấy E, thêm H (10):
#     Tổng trọng số đến H = 11 + 10 = 21
#     Hàng đợi = [(G, [S, C, F, G], 26), (H, [S, A, B, E, H], 21)]
#     Đã thăm = {S, A, C, B, D, F, E, G, H}
# 9.Lấy H, là đích → Dừng.
# Kết quả BFS:
# Đường đi: S → A → B → E → H
#
# Tổng trọng số: 21
#
# Không phải ngắn nhất về trọng số (vì BFS không tối ưu cho trọng số).
# 2. DFS
# 1.Khởi tạo:
# Ngăn xếp = [(S, [S], 0)]
# Đã thăm = {S}
# 2.Lấy S, thêm A trước (theo thứ tự):
# Ngăn xếp = [(A, [S, A], 2)]
# Đã thăm = {S, A}
# 3.Lấy A, thêm B (3):
# Tổng trọng số = 2 + 3 = 5
# Ngăn xếp = [(B, [S, A, B], 5)]
# Đã thăm = {S, A, B}
# 4.Lấy B, thêm E (6):
# Tổng trọng số = 5 + 6 = 11
# Ngăn xếp = [(E, [S, A, B, E], 11)]
# Đã thăm = {S, A, B, E}
# 5.Lấy E, thêm H (10):
# Tổng trọng số = 11 + 10 = 21
# Ngăn xếp = [(H, [S, A, B, E, H], 21)]
# Đã thăm = {S, A, B, E, H}
# 6.Lấy H, là đích → Dừng.
# Kết quả DFS:
# Đường đi: S → A → B → E → H
# Tổng trọng số: 21
#
# Nhận xét:
# Thuật toán	Đường đi tìm được	Tổng trọng số	Tối ưu trọng số?	Ghi chú
# BFS	S → A → B → E → H	21	Không chắc	Tìm theo số cạnh
# DFS	S → A → B → E → H	21	Không chắc	Tìm theo nhánh sâu
# # Bài 2
#
# 1. BFS thủ công – Ghi tất cả đường đi từ S đến H
# Khởi tạo:
# Queue = [(S, [S])]
# Visited = {}
# Paths to H = []
# Lặp BFS:
# Lấy (S, [S])
# → Các kề: A, D, E
# → Thêm vào queue:
# (A, [S, A])
# (D, [S, D])
# (E, [S, E])
# Lấy (A, [S, A])
# → Các kề: B, D, E
# → Thêm vào queue:
# (B, [S, A, B])
# (D, [S, A, D])
# (E, [S, A, E])
# Lấy (D, [S, D])
# → Kề: E
# → Thêm: (E, [S, D, E])
# Lấy (E, [S, E])
# → Kề: F, H
# Đến H → Thêm [S, E, H] vào Paths
# → Thêm:
# (F, [S, E, F])
# (H, [S, E, H])
# Lấy (B, [S, A, B])
# → Kề: C, E, F
# → Thêm:
# (C, [S, A, B, C])
# (E, [S, A, B, E])
# (F, [S, A, B, F])
# Lấy (D, [S, A, D])
# → Kề: E
# → Thêm:
# (E, [S, A, D, E])
# Lấy (E, [S, A, E])
# → Kề: F, H
# Đến H → Thêm [S, A, E, H] vào Paths
# → Thêm:
# (F, [S, A, E, F])
# (H, [S, A, E, H])
# Lấy (E, [S, D, E])
# → Kề: F, H
# Đến H → Thêm [S, D, E, H]
# → Thêm:
# (F, [S, D, E, F])
# (H, [S, D, E, H])
# Lấy (F, [S, E, F])
# → Kề: G, H
# Đến H → Thêm [S, E, F, H]
# → Thêm:
# (G, [S, E, F, G])
# (H, [S, E, F, H])
# Lấy (H, [S, E, H]) → Gặp đích rồi → bỏ qua
# Lấy (C, [S, A, B, C])
# → Kề: F, G
# → Thêm:
# (F, [S, A, B, C, F])
# (G, [S, A, B, C, G])
# Lấy (E, [S, A, B, E])
# → Kề: F, H
# Đến H → Thêm [S, A, B, E, H]
# → Thêm:
# (F, [S, A, B, E, F])
# (H, [S, A, B, E, H])
# Lấy (F, [S, A, B, F])
# → Kề: G, H
# Đến H → Thêm [S, A, B, F, H]
# → Thêm:
# (G, [S, A, B, F, G])
# (H, [S, A, B, F, H])
# Lấy (E, [S, A, D, E])
# → Kề: F, H
# Đến H → Thêm [S, A, D, E, H]
# → Thêm:
# (F, [S, A, D, E, F])
# (H, [S, A, D, E, H])
# Lấy (F, [S, A, E, F])
# → Kề: G, H
# Đến H → Thêm [S, A, E, F, H]
# → Thêm:
# (G, [S, A, E, F, G])
# (H, [S, A, E, F, H])
# Lấy (H, [S, A, E, H]) → Đã đích
# Tiếp tục như vậy, BFS có thể tìm ra rất nhiều đường khác, nhưng ở đây ta dừng sau khi đã thấy các đường hợp lý độ dài ngắn đến trung bình.
# | STT | Đường đi từ S đến H   | Số cạnh |
# | --- | --------------------- | ------- |
# | 1   | S → E → H             | 2       |
# | 2   | S → A → E → H         | 3       |
# | 3   | S → D → E → H         | 3       |
# | 4   | S → E → F → H         | 3       |
# | 5   | S → A → B → E → H     | 4       |
# | 6   | S → A → B → F → H     | 4       |
# | 7   | S → A → D → E → H     | 4       |
# | 8   | S → A → E → F → H     | 4       |
# | 9   | S → A → B → C → F → H | 5       |
# | 10  | S → A → B → E → F → H | 5       |
# | 11  | S → A → B → C → G → H | 5       |
# | 12  | S → A → B → F → G → H | 5       |
# | 13  | S → A → E → F → G → H | 5       |
# | 14  | S → D → E → F → H     | 4       |
# | 15  | S → D → E → F → G → H | 5       |
#
# 2. DFS chỉ tìm một đường đầu tiên đến H theo chiều sâu nhất có thể.
#
# Ví dụ:
#
# S → A → B → C → G → H
#
# hoặc S → D → E → F → G → H tùy theo thứ tự duyệt.

# %%
# Trả lời câu hỏi lý thuyết ở đây:

# 1. 


# 2.

# %%
# Minh hoạt thủ công ở đây:

# %% [markdown]
# ## Bài Tập lập trình

# %% [markdown]
# #### Bài Tập Lập Trình: BFS trên Đồ Thị Mẫu 2
# Chạy BFS trên **Đồ thị mẫu 2** với chú thích chi tiết.

# %%
# code here

# %% [markdown]
# #### Bài Tập Lập Trình: DFS trên Đồ Thị Mẫu 2
# Chạy DFS trên **Đồ thị mẫu 2** với chú thích chi tiết.

# %%
# code here

# %% [markdown]
# ### Sửa mã BFS để đếm số nút đã thăm trên **Đồ thị mẫu 4**. In ra kết quả và đảm bảo mã có chú thích đầy đủ.

# %%
# code here

# %%
# code here

# %%
# code here

# %% [markdown]
# ## Bài Tập Về Nhà
# - **Thời hạn nộp**: 7 ngày kể từ ngày thực hành (tính đến 23:59 ngày 6/6/2025).
# - **Yêu cầu**:
#   - Hoàn thành các bài tập dưới đây.
#   - Nộp file Jupyter Notebook (.ipynb) đã hoàn thành và báo cáo (.docx hoặc .pdf).
#   - Báo cáo cần bao gồm:
#     - Minh họa thủ công cho ít nhất một đồ thị (Đồ thị mẫu 6 hoặc 7).
#     - Kết quả chạy mã Python với chú thích đầy đủ.
#     - Trả lời các câu hỏi lý thuyết và phân tích hạn chế của BFS/DFS.
#
# ### Đồ Thị Mẫu Phức Tạp
#
# #### Đồ Thị Mẫu 6: Có Trọng Số, Nhiều Đường Đi
# ##### Mermaid Diagram
# ```mermaid
# graph TD
#     S -->|2| A
#     S -->|5| C
#     A -->|3| B
#     A -->|4| D
#     B -->|6| E
#     C -->|7| D
#     C -->|9| F
#     D -->|8| E
#     E -->|10| H
#     F -->|12| G
#     G -->|15| H
# ```
# - **Các cạnh và trọng số**:
#   - S-A: 2, S-C: 5, A-B: 3, A-D: 4, B-E: 6, C-D: 7, C-F: 9, D-E: 8, E-H: 10, F-G: 12, G-H: 15.
# - **Đặc điểm**: Nhiều đường đi từ S đến H, có chu trình (A-D-E-B-A).
#
# #### Đồ Thị Mẫu 7: Không Trọng Số, Mật Độ Cao
# ##### Mermaid Diagram
# ```mermaid
# graph TD
#     S --> A
#     S --> D
#     S --> E
#     A --> B
#     A --> D
#     A --> E
#     B --> C
#     B --> E
#     B --> F
#     C --> F
#     C --> G
#     D --> E
#     E --> F
#     E --> H
#     F --> G
#     F --> H
#     G --> H
#
# ```
# - **Các cạnh**: S-A, S-D, S-E, A-B, A-D, A-E, B-C, B-E, B-F, C-F, C-G, D-E, E-F, E-H, F-G, F-H, G-H.
# - **Đặc điểm**: Mật độ cạnh cao, nhiều chu trình, nhiều đường đi từ S đến H.
#
# ### Câu Hỏi Lý Thuyết
# 1. Phân tích tại sao BFS và DFS không đảm bảo đường đi có tổng trọng số nhỏ nhất trên **Đồ thị mẫu 6**. Đưa ra một ví dụ cụ thể về đường đi không tối ưu.
# 2. Trong **Đồ thị mẫu 7**, tại sao BFS có thể tìm nhiều đường đi có độ dài bằng nhau từ S đến H? DFS có khả năng này không? Giải thích.
#
# ### Bài Tập Minh Họa Thủ Công
# 1. Thực hiện BFS và DFS thủ công trên **Đồ thị mẫu 6** để tìm đường từ S đến H. Ghi lại trạng thái hàng đợi/ngăn xếp, tập đã thăm, và tổng trọng số.
# 2. Thực hiện BFS và DFS thủ công trên **Đồ thị mẫu 7**. Ghi lại tất cả các đường đi từ S đến H mà BFS tìm được.
#
# ### Bài Tập Lập Trình
# 1. Viết mã Python để chạy BFS và DFS trên **Đồ thị mẫu 6** và **Đồ thị mẫu 7**. Định nghĩa đồ thị dưới dạng từ điển và thêm chú thích chi tiết.
# 2. Sửa mã BFS để lưu và in tất cả các đường đi từ S đến H trên **Đồ thị mẫu 7** (không trọng số). Đảm bảo mã có chú thích đầy đủ.
# 3. Thêm một cạnh mới vào **Đồ thị mẫu 6** (ví dụ: B-H với trọng số 20). Chạy lại BFS và DFS, phân tích sự thay đổi trong đường đi và tổng trọng số.
#
# ### Bài Tập Nâng Cao
# 1. Đo thời gian chạy của BFS và DFS trên **Đồ thị mẫu 6** và **Đồ thị mẫu 7** bằng thư viện `time`. So sánh hiệu suất và thêm chú thích vào mã.
# 2. Thiết kế một đồ thị có trọng số với ít nhất 10 nút và 15 cạnh. Chạy BFS và DFS, phân tích đường đi và tổng trọng số. Đảm bảo mã có chú thích chi tiết.

# %% [markdown]
# # Trả lời câu hỏi lý thuyết
#
# 3. Tại sao BFS và DFS không đảm bảo đường đi có tổng trọng số nhỏ nhất trên Đồ thị mẫu 6?
# Phân tích chung:
# Cả BFS (Breadth-First Search) và DFS (Depth-First Search) đều không sử dụng thông tin trọng số của các cạnh.
# Vì vậy, chúng chỉ quan tâm đến số lượng cạnh (chiều dài đường đi), chứ không phải tổng trọng số của đường đi.
# Điều này dẫn đến việc có thể chọn đường đi ngắn hơn về số cạnh nhưng lại có tổng trọng số lớn hơn.
# Ví dụ cụ thể trên Đồ thị mẫu 6:
# Các đường đi từ S đến H:
# Đường đi 1: S → A → B → E → H
# Trọng số: 2 (S-A) + 3 (A-B) + 6 (B-E) + 10 (E-H) = 21
# Đường đi 2: S → C → F → G → H
# Trọng số: 5 (S-C) + 9 (C-F) + 12 (F-G) + 15 (G-H) = 41
# Đường đi 3: S → A → D → E → H
# Trọng số: 2 + 4 + 8 + 10 = 24
# Giả sử BFS chạy từ S đến H:
# Nó có thể ưu tiên đường đi ngắn hơn về số cạnh, ví dụ:
# S → C → F → G → H (4 cạnh)
# Nhưng đây là đường có trọng số rất lớn (41), không phải tối ưu.
# Tương tự với DFS:
# DFS có thể đi theo nhánh sâu như:
# S → A → D → E → H (tổng trọng số: 24)
# Trong khi đó, S → A → B → E → H có tổng trọng số nhỏ hơn (21), nhưng DFS có thể bỏ qua vì không “thử hết” các nhánh đúng cách nếu không có backtracking tốt.
#  Kết luận:
# Cả BFS và DFS đều không tối ưu trọng số vì không dùng thông tin trọng số khi tìm đường đi.
# Nếu cần tìm đường đi có tổng trọng số nhỏ nhất, nên dùng Dijkstra hoặc A*.
# 4. Trong Đồ thị mẫu 7, tại sao BFS có thể tìm nhiều đường đi có độ dài bằng nhau từ S đến H? DFS có khả năng này không?
# Đặc điểm của đồ thị mẫu 7:
# Đồ thị không trọng số, mật độ cao.
# Mỗi cạnh có cùng “trọng số giả định” là 1.
# Nhiều đường đi từ S đến H có cùng số bước.
# BFS (Breadth-First Search):
# BFS hoạt động theo lớp (level):
# Tìm tất cả các đỉnh cách S một cạnh, rồi hai cạnh, v.v.
# Khi BFS tìm thấy đỉnh H, nó đảm bảo rằng:
# Đó là đường đi ngắn nhất theo số cạnh từ S đến H.
# Nếu tiếp tục tìm, BFS có thể tìm ra nhiều đường đi khác cũng có cùng độ dài, vì nó khám phá tất cả các đường đi ngắn nhất đầu tiên.
# Ví dụ:
# Đường đi 1: S → E → H (2 cạnh)
# Đường đi 2: S → A → E → H (3 cạnh)
# Đường đi 3: S → D → E → H (3 cạnh)
# ➡️ BFS sẽ phát hiện ra tất cả các đường đi có độ dài tối thiểu đến H, và có thể ghi nhận nhiều đường cùng độ dài nếu cần.
# DFS (Depth-First Search):
# DFS đi sâu vào một nhánh trước khi quay lại.
# Nó không ưu tiên các đường ngắn hơn.
# Vì thế, nó không đảm bảo tìm được đường đi ngắn nhất, hoặc tìm tất cả các đường đi ngắn nhất.
# Ví dụ:
# DFS có thể đi theo nhánh dài như:
# S → A → B → C → G → H (nhiều bước hơn)
# Mặc dù vẫn đến H, nhưng không đảm bảo độ dài tối thiểu.
# DFS chỉ tìm một đường đi duy nhất tại một thời điểm, trừ khi ta lưu lại và so sánh nhiều nhánh, điều mà DFS không làm mặc định.
# Tóm tắt so sánh
# Thuật toán	Có đảm bảo đường ngắn nhất (theo số cạnh)?	Tìm nhiều đường ngắn như nhau?	Tối ưu tổng trọng số?
# BFS	 Có	    Có thể	 Không
# DFS	 Không  Không	 Không

# %% [markdown]
# # Bài tập minh hoạ thủ công
#
# 1. BFS thủ công – Ghi tất cả đường đi từ S đến H
# Khởi tạo:
# Queue = [(S, [S])]
# Visited = {}
# Paths to H = []
# Lặp BFS:
# Lấy (S, [S])
# → Các kề: A, D, E
# → Thêm vào queue:
# (A, [S, A])
# (D, [S, D])
# (E, [S, E])
# Lấy (A, [S, A])
# → Các kề: B, D, E
# → Thêm vào queue:
# (B, [S, A, B])
# (D, [S, A, D])
# (E, [S, A, E])
# Lấy (D, [S, D])
# → Kề: E
# → Thêm: (E, [S, D, E])
# Lấy (E, [S, E])
# → Kề: F, H
# Đến H → Thêm [S, E, H] vào Paths
# → Thêm:
# (F, [S, E, F])
# (H, [S, E, H])
# Lấy (B, [S, A, B])
# → Kề: C, E, F
# → Thêm:
# (C, [S, A, B, C])
# (E, [S, A, B, E])
# (F, [S, A, B, F])
# Lấy (D, [S, A, D])
# → Kề: E
# → Thêm:
# (E, [S, A, D, E])
# Lấy (E, [S, A, E])
# → Kề: F, H
# Đến H → Thêm [S, A, E, H] vào Paths
# → Thêm:
# (F, [S, A, E, F])
# (H, [S, A, E, H])
# Lấy (E, [S, D, E])
# → Kề: F, H
# Đến H → Thêm [S, A, B, E, H]
# → Thêm:
# (F, [S, A, B, E, F])
# (H, [S, A, B, E, H])
# Lấy (F, [S, A, B, F])
# → Kề: G, H
# Đến H → Thêm [S, A, B, F, H]
# → Thêm:
# (G, [S, A, B, F, G])
# (H, [S, A, B, F, H])
# Lấy (E, [S, A, D, E])
# → Kề: F, H
# Đến H → Thêm [S, A, D, E, H]
# → Thêm:
# (F, [S, A, D, E, F])
# (H, [S, A, D, E, H])
# Lấy (F, [S, A, E, F])
# → Kề: G, H
# Đến H → Thêm [S, A, E, F, H]
# → Thêm:
# (G, [S, A, E, F, G])
# (H, [S, A, E, F, H])
# Lấy (H, [S, A, E, H]) → Đã đích
# Tiếp tục như vậy, BFS có thể tìm ra rất nhiều đường khác, nhưng ở đây ta dừng sau khi đã thấy các đường hợp lý độ dài ngắn đến trung bình.
# | STT | Đường đi từ S đến H   | Số cạnh |
# | --- | --------------------- | ------- |
# | 1   | S → E → H             | 2       |
# | 2   | S → A → E → H         | 3       |
# | 3   | S → D → E → H         | 3       |
# | 4   | S → E → F → H         | 3       |
# | 5   | S → A → B → E → H     | 4       |
# | 6   | S → A → B → F → H     | 4       |
# | 7   | S → A → D → E → H     | 4       |
# | 8   | S → A → E → F → H     | 4       |
# | 9   | S → A → B → C → F → H | 5       |
# | 10  | S → A → B → E → F → H | 5       |
# | 11  | S → A → B → C → G → H | 5       |
# | 12  | S → A → B → F → G → H | 5       |
# | 13  | S → A → E → F → G → H | 5       |
# | 14  | S → D → E → F → H     | 4       |
# | 15  | S → D → E → F → G → H | 5       |
# 2.
# Bước 1:
# Queue ban đầu: [[S]]
# Bước 2:
# Mở rộng S:
# Thêm các đường đi mới:
# [S → A], [S → D], [S → E]
# Queue: [[S A], [S D], [S E]]
# Bước 3:
# Mở rộng S → A:
# A → B, D, E
# Tạo mới: [S A B], [S A D], [S A E]
# Queue: [[S D], [S E], [S A B], [S A D], [S A E]]
# Bước 4:
# Mở rộng S → D:
# D → E
# Tạo mới: [S D E]
# Queue: [[S E], [S A B], [S A D], [S A E], [S D E]]
# Bước 5:
# Mở rộng S → E:
# E → F, H
# Tạo mới: [S E F], [S E H]
# Tìm thấy đường đi đầu tiên: [S E H]
# Queue: [[S A B], [S A D], [S A E], [S D E], [S E F]]
# Bước 6:
# Mở rộng S A B:
# B → C, E, F
# Tạo mới: [S A B C], [S A B E], [S A B F]
# Queue: [[S A D], [S A E], [S D E], [S E F], [S A B C], [S A B E], [S A B F]]
# Bước 7:
# Mở rộng S A D: D → E
# [S A D E]
# Queue: [[S A E], [S D E], [S E F], [S A B C], [S A B E], [S A B F], [S A D E]]
# Bước 8:
# Mở rộng S A E: E → F, H
# [S A E F], [S A E H]
# Đường đi: [S A E H]
# Queue: ...
# Bước 9+: Tiếp tục mở rộng các nhánh còn lại và ghi nhận thêm các đường đi đến H.
# Tổng hợp các đường đi từ S đến H tìm được bằng BFS
# Dưới đây là các đường đi từ S đến H mà BFS tìm được, theo thứ tự tăng độ dài:
#
# STT	Đường đi từ S đến H	Độ dài
# 1	S → E → H	2 cạnh
# 2	S → A → E → H	3 cạnh
# 3	S → D → E → H	3 cạnh
# 4	S → A → B → E → H	4 cạnh
# 5	S → A → B → F → H	4 cạnh
# 6	S → A → E → F → H	4 cạnh
# 7	S → E → F → H	3 cạnh
# 8	S → A → B → C → G → H	5 cạnh
# 9	S → A → B → C → F → H	5 cạnh
# 10	S → A → B → C → F → G → H	6 cạnh
#
# ( Có thể còn vài đường đi khác nếu tiếp tục mở rộng BFS đến hết.)
#
# Ghi chú:
# Tất cả các đường có độ dài 2 hoặc 3 cạnh là các đường ngắn nhất từ S đến H.
#
# BFS đảm bảo liệt kê các đường ngắn trước, dài sau.
#
# Để tìm tất cả đường đi, cần duyệt hết các khả năng trong đồ thị — quá trình có thể tốn nhiều thời gian ở đồ thị mật độ cao.

# %%
# code here

# %%
# code here

# %%
# code here

# %%
# code here

# %%
# code here

# %% [markdown]
# ## Hướng Dẫn Nộp Bài
# - **Về nhà**:
#   - Nộp file `.ipynb` này và báo cáo trước 23:59 ngày 6/6/2025 lên github.
#   - Báo cáo cần trình bày rõ ràng, có cấu trúc, bao gồm minh họa thủ công, kết quả mã nguồn với chú thích, và phân tích trong README.
